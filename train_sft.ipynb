# %%
# !llamafactory-cli webui
# Out:
# Using config file: /etc/orion/env/env.conf
# 09/04/2024 02:04:23 - INFO - llamafactory.hparams.parser - Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: False, compute dtype: torch.bfloat16
# [INFO|tokenization_utils_base.py:2180] 2024-09-04 02:04:23,677 >> loading file vocab.json
# [INFO|tokenization_utils_base.py:2180] 2024-09-04 02:04:23,678 >> loading file merges.txt
# [INFO|tokenization_utils_base.py:2180] 2024-09-04 02:04:23,678 >> loading file tokenizer.json
# [INFO|tokenization_utils_base.py:2180] 2024-09-04 02:04:23,678 >> loading file added_tokens.json
# [INFO|tokenization_utils_base.py:2180] 2024-09-04 02:04:23,678 >> loading file special_tokens_map.json
# [INFO|tokenization_utils_base.py:2180] 2024-09-04 02:04:23,678 >> loading file tokenizer_config.json
# [INFO|tokenization_utils_base.py:2426] 2024-09-04 02:04:24,142 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

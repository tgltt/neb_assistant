# %%
# !finetune/finetune_lora_single_gpu.sh
# Out:
# [2024-08-29 22:18:37,441] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.1
#  [WARNING]  using untested triton version (2.1.0), only 1.0.0 is known to be compatible
# /root/miniconda3/lib/python3.11/site-packages/transformers/deepspeed.py:23: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(
# Using config file: /etc/orion/env/env.conf
# The model is automatically converting to bf16 for faster inference. If you want to disable the automatic precision, please manually add bf16/fp16/fp32=True to "AutoModelForCausalLM.from_pretrained".
# ...

# %%
from torch.nn import RM
